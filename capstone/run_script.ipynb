# %%
import pandas as pd
import json
from pandas.io.json import json_normalize
import glob

# %%
fnames = glob.glob('yelp_dataset_challenge_academic_dataset/yelp*.json')
fnames
# Out:
# ['yelp_dataset_challenge_academic_dataset/yelp_academic_dataset_review.json',
#  'yelp_dataset_challenge_academic_dataset/yelp_academic_dataset_business.json',
#  'yelp_dataset_challenge_academic_dataset/yelp_academic_dataset_user.json',
#  'yelp_dataset_challenge_academic_dataset/yelp_academic_dataset_checkin.json',
#  'yelp_dataset_challenge_academic_dataset/yelp_academic_dataset_tip.json']

# %%
# read in data set
def read_data(fname):
    data = []
    with open(fname) as f:
        for line in f:
            data.append(json.loads(line))

    df = pd.DataFrame(data)
    return df

# %%
# use recursion to find nested data

# find nested data
def find_dictionary(df):
    return df.columns[df.apply(lambda x: isinstance(x[0], dict))]

# create dataframe from nested data
def create_df_col(df, col):
    pass

# %%
df = read_data(fnames[2])

# %%
col = find_dictionary(df)
comp = json_normalize(list(df.compliments))
vote = json_normalize(list(df.votes))

# %%
comp.join(vote, rsuffix='vote')
# Out:
#         cool  cute  funny   hot  list  more  note  photos  plain  profile  \
# 0         78    15     11    48   NaN     3    20      15     25        8
# 1       1521   209    561  1032    37   129   589     287    921      110
# 2        145    23    122   102     4    19    82      23     86        9
# 3        NaN     2    NaN   NaN   NaN   NaN   NaN     NaN    NaN      NaN
# 4          1     2    NaN     1   NaN     1     1     NaN      2      NaN
# 5       3420   274   1462  2599    89   218  1009    1854   3902      220
# 6          3     1      1     1     5   NaN     1       4      4        1
# 7         14     4      2     8     1     1     5     NaN      6        2
# 8          1   NaN    NaN     1   NaN   NaN   NaN     NaN      5      NaN
# 9          3     1      8     5   NaN     2     3       1      5        1
# 10         3   NaN    NaN     1   NaN   NaN   NaN       1      2      NaN
# 11       211    82     70   265     3    16    85      57    102       10
# ...

# %%
# save to sqlite
